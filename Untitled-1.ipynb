# %%
import geopandas as gpd

# %%
ak_shape = gpd.read_file(r"C:\Users\achyu\git\cs132election\ak_2020\ak_2020.shp")

ak_shape

# %%
ak_prez = gpd.GeoDataFrame(ak_shape.iloc[:, 0:9])
ak_prez

# %%
ak_prez = ak_prez.set_geometry(ak_shape['geometry'])
ak_prez

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize = (30,30))
ak_shape.plot(ax = ax)

# %%
fig, ax = plt.subplots(figsize = (30,30))
ak_prez.plot(ax = ax)

# %%
import max_heap

# %%
max_list = []
for i in range(len(ak_prez)):
    row = ak_prez.loc[i][2:9]
    heap = max_heap.MaxHeap(10)
    for item in row: heap.insert(item)
    max_val = heap.extractMax()
    max_list.append([max_val])

for index, row in ak_prez.iterrows():
    max_index = row[2:9].idxmax()
    max_list[index].append(max_index)
    
    color = max_index[6]
    if color == "R": color_val = "red"
    elif color == "D": color_val = "blue"
    else: color_val = "green"
    max_list[index].append(color_val)

for i in range(len(ak_prez)):
    ak_prez.loc[i, "max_color"] = max_list[i][2]
    ak_prez.loc[i, "winner"] = max_list[i][1]
    ak_prez.loc[i, "win_count"] = max_list[i][0]

ak_prez

# %%
fig, ax = plt.subplots(figsize=(10, 10))
ak_prez.plot(ax=ax, color=ak_prez['max_color'])

plt.title("GeoDataFrame with Maximum Value Colors")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()

# %%
al_shape = gpd.read_file(r"C:\Users\achyu\git\cs132election\al_2020\al_2020.shp")
al_shape

# %%
fig, ax = plt.subplots(figsize=(10, 10))
al_shape.plot(ax=ax)

# %%
al_prez = gpd.GeoDataFrame()
al_prez = al_prez.set_geometry(al_shape["geometry"])
add_columns = []
for col in al_shape:
    if col[3:6] == "PRE":
        add_columns.append(col)

for col in add_columns:
    al_prez[col] = al_shape[col]

al_prez

# %%
al_shape = gpd.read_file(r"al_2020.zip")

al_prez = gpd.GeoDataFrame()
al_prez = al_prez.set_geometry(al_shape["geometry"])
add_columns = []
for col in al_shape:
    if col[3:6] == "PRE":
        add_columns.append(col)

for col in add_columns:
    al_prez[col] = al_shape[col]

al_prez

# %%
numeric_columns = al_prez.select_dtypes(include='number')  # Select only numeric columns
max_indices = numeric_columns.idxmax(axis=1)  # Get the index of max value for each row
al_prez["winners"] = max_indices
al_prez

# %%
win_count = []
for index, row in al_prez.iterrows():
    
    numeric_values = al_prez.loc[index, numeric_columns.columns].tolist() # get the row of the numbers
    heap = max_heap.MaxHeap(20)
    for item in numeric_values:
        heap.insert(item)
    max_val = heap.extractMax()
    win_count.append(max_val)

al_prez["win_count"] = win_count
al_prez

# %%
for i, winner in enumerate(al_prez["winners"]):
    if winner[6] == "R": color = "red"
    elif winner[6] == "D": color = "blue"
    elif winner[6] == "G": color = "green"
    elif winner[6] == "L": color = "yellow"
    else: color = "grey"

    al_prez.loc[i, "max_color"] = color

al_prez

# %%
al_shape = gpd.read_file(r"C:\Users\achyu\git\cs132election\state_zip\co_2020.zip")

# creating geo data frame
al_prez = gpd.GeoDataFrame()

# create subset with only presidents and geometry
al_prez = al_prez.set_geometry(al_shape["geometry"])
add_columns = []
for col in al_shape:
    if col[3:6] == "PRE":
        add_columns.append(col)

# adding filtered columns with presidents
for col in add_columns:
    al_prez[col] = al_shape[col]

# finding the winners by row and saving as a separate column
numeric_columns = al_prez.select_dtypes(include='number')  # Select only numeric columns
max_indices = numeric_columns.idxmax(axis=1)  # Get the index of max value for each row
al_prez["winners"] = max_indices

# using heap to extract the maximum from each row
win_count = []
for index, row in al_prez.iterrows():
    numeric_values = al_prez.loc[index, numeric_columns.columns].tolist() # get the row of the numbers
    heap = max_heap.MaxHeap(20)
    for item in numeric_values:
        heap.insert(item)
    max_val = heap.extractMax()
    win_count.append(max_val)

al_prez["win_count"] = win_count

# setting the color depending on the winner of that particular row
for i, winner in enumerate(al_prez["winners"]):
    if winner[6] == "R": color = "red"
    elif winner[6] == "D": color = "blue"
    elif winner[6] == "G": color = "green"
    elif winner[6] == "L": color = "yellow"
    else: color = "grey"
    
    al_prez.loc[i, "max_color"] = color

al_prez

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import tkinter
from tkinter import ttk
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg, NavigationToolbar2Tk)
from matplotlib.backend_bases import key_press_handler

option = {
    "Alabama": "al",
    "Alaska": "ak",
    "Arizona": "az",
    "Arkansas": "ar",
    "California": "ca",
    "Colorado": "co",
    "Connecticut": "ct",
    "Delaware": "de",
    "Florida": "fl",
    "Georgia": "ga",
    "Hawaii": "hi",
    "Idaho": "id",
    "Illinois": "il",
    "Indiana": "in",
    "Iowa": "ia",
    "Kansas": "ks",
    "Kentucky": "ky",
    "Louisiana": "la",
    "Maine": "me",
    "Maryland": "md",
    "Massachusetts": "ma",
    "Michigan": "mi",
    "Minnesota": "mn",
    "Mississippi": "ms",
    "Missouri": "mo",
    "Montana": "mt",
    "Nebraska": "ne",
    "Nevada": "nv",
    "New Hampshire": "nh",
    "New Jersey": "nj",
    "New Mexico": "nm",
    "New York": "ny",
    "North Carolina": "nc",
    "North Dakota": "nd",
    "Ohio": "oh",
    "Oklahoma": "ok",
    "Oregon": "or",
    "Pennsylvania": "pa",
    "Rhode Island": "ri",
    "South Carolina": "sc",
    "South Dakota": "sd",
    "Tennessee": "tn",
    "Texas": "tx",
    "Utah": "ut",
    "Vermont": "vt",
    "Virginia": "va",
    "Washington": "wa",
    "West Virginia": "wv",
    "Wisconsin": "wi",
    "Wyoming": "wy"
}

def drawMap(dataset):
    for widget in frame.winfo_children():
        widget.destroy()
    fig,ax = plt.subplots(figsize=(5,4))
    dataset.plot(ax=ax, color=dataset.color)
    canvas = FigureCanvasTkAgg(fig, master=frame)
    canvas.draw()
    canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
    toolbar = NavigationToolbar2Tk(canvas, frame)
    toolbar.update()
    canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)

def updateState():
    zipfile = r"C:\Users\achyu\git\cs132election\state_zip" + "/" + str(option[dropdown.get()]) + "_2020.zip"
    us = gpd.read_file(zipfile)
    
    winner = []
    for i in range(len(us)):
        if us.G20PREDBID[i] > us.G20PRERTRU[i]:
            winner.append("blue")
        elif us.G20PREDBID[i] < us.G20PRERTRU[i]:
            winner.append("red")
        else:
            winner.append("grey")
    d = {'color': winner, 'geometry': us.geometry}
    dataset = gpd.GeoDataFrame(d)
    drawMap(dataset)

root = tkinter.Tk()
root.wm_title("Political Heatmap")
frame = ttk.Frame(root)
frame.pack(fill=tkinter.BOTH, expand=True)

dropdown = tkinter.StringVar()
dropdown.set("Alabama")
drop = tkinter.OptionMenu(root, dropdown, *option.keys())
drop.pack(side=tkinter.LEFT)

update = tkinter.Button(root,text="Update",command=updateState).pack(side=tkinter.LEFT)

def _quit():
    root.quit()
    root.destroy()

button = tkinter.Button(master=root, text="Quit", command=_quit)
button.pack(side=tkinter.RIGHT,padx=5)

updateState()

tkinter.mainloop()

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import tkinter
from new_shape_generator import generator
from tkinter import ttk
from matplotlib.backends.backend_tkagg import (FigureCanvasTkAgg, NavigationToolbar2Tk)
from matplotlib.backend_bases import key_press_handler

option = {
    "Alabama": "al",
    "Alaska": "ak",
    "Arizona": "az",
    "Arkansas": "ar",
    "California": "ca",
    "Colorado": "co",
    "Connecticut": "ct",
    "Delaware": "de",
    "Florida": "fl",
    "Georgia": "ga",
    "Hawaii": "hi",
    "Idaho": "id",
    "Illinois": "il",
    "Indiana": "in",
    "Iowa": "ia",
    "Kansas": "ks",
    "Kentucky": "ky",
    "Louisiana": "la",
    "Maine": "me",
    "Maryland": "md",
    "Massachusetts": "ma",
    "Michigan": "mi",
    "Minnesota": "mn",
    "Mississippi": "ms",
    "Missouri": "mo",
    "Montana": "mt",
    "Nebraska": "ne",
    "Nevada": "nv",
    "New Hampshire": "nh",
    "New Jersey": "nj",
    "New Mexico": "nm",
    "New York": "ny",
    "North Carolina": "nc",
    "North Dakota": "nd",
    "Ohio": "oh",
    "Oklahoma": "ok",
    "Oregon": "or",
    "Pennsylvania": "pa",
    "Rhode Island": "ri",
    "South Carolina": "sc",
    "South Dakota": "sd",
    "Tennessee": "tn",
    "Texas": "tx",
    "Utah": "ut",
    "Vermont": "vt",
    "Virginia": "va",
    "Washington": "wa",
    "West Virginia": "wv",
    "Wisconsin": "wi",
    "Wyoming": "wy"
}

def drawMap(state_shape):
    for widget in frame.winfo_children():
        widget.destroy()
    fig, ax = plt.subplots(figsize=(5, 4))
    state_shape.plot(ax=ax, color=state_shape['max_color'])
    canvas = FigureCanvasTkAgg(fig, master=frame)
    canvas.draw()
    canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)
    toolbar = NavigationToolbar2Tk(canvas, frame)
    toolbar.update()
    canvas.get_tk_widget().pack(side=tkinter.TOP, fill=tkinter.BOTH, expand=1)

def updateState():
    zipfile = r"C:\Users\achyu\git\cs132election\state_zip" + "/" + str(option[dropdown.get()]) + "_2020.zip"
    #us = gpd.read_file(zipfile)
    state_shape = generator(zipfile)
    drawMap(state_shape)

root = tkinter.Tk()
root.wm_title("Political Heatmap")
frame = ttk.Frame(root)
frame.pack(fill=tkinter.BOTH, expand=True)

dropdown = tkinter.StringVar()
dropdown.set("Alabama")
drop = tkinter.OptionMenu(root, dropdown, *option.keys())
drop.pack(side=tkinter.LEFT)

update = tkinter.Button(root,text="Update",command=updateState).pack(side=tkinter.LEFT)

def _quit():
    root.quit()
    root.destroy()

button = tkinter.Button(master=root, text="Quit", command=_quit)
button.pack(side=tkinter.RIGHT,padx=5)

updateState()

tkinter.mainloop()

# %%
zipfile = r"C:\Users\achyu\git\cs132election\state_zip" + "/" + str(option[dropdown.get()]) + "_2020.zip"
us = gpd.read_file(zipfile)
from new_shape_generator import generator

state_shape = generator(zipfile)
state_shape
# Out:
#                                                geometry  G20PRERTRU  \
# 0     POLYGON ((-86.90894 31.96167, -86.90632 31.961...          25
# 1     POLYGON ((-86.71867 31.73289, -86.71864 31.732...         100
# 2     POLYGON ((-87.05166 31.11854, -87.04869 31.118...         265
# 3     POLYGON ((-86.95858 31.16635, -86.95844 31.166...         180
# 4     POLYGON ((-86.82985 31.02083, -86.82983 31.020...          68
# ...                                                 ...         ...
# 1967  POLYGON ((-85.29208 33.04356, -85.29168 33.044...         354
# 1968  POLYGON ((-85.25089 33.03025, -85.25105 33.030...         330
# 1969  POLYGON ((-85.37286 32.73030, -85.37315 32.730...         278
# 1970  POLYGON ((-85.37797 32.73308, -85.37678 32.733...         351
# 1971  MULTIPOLYGON (((-86.81821 34.18173, -86.81821 ...         732
#
#       G20PREDBID  G20PRELJOR  G20PREOWRI     winners  win_count max_color
# 0             37           2           0  G20PREDBID         37      blue
# 1             50           0           0  G20PRERTRU        100       red
# 2             60           3           0  G20PRERTRU        265       red
# 3            143           2           1  G20PRERTRU        180       red
# 4              2           0           0  G20PRERTRU         68       red
# ...          ...         ...         ...         ...        ...       ...
# 1967         126           4           0  G20PRERTRU        354       red
# 1968          90           1           0  G20PRERTRU        330       red
# 1969         125           1           0  G20PRERTRU        278       red
# 1970         392           7           1  G20PREDBID        392      blue
# 1971         105          17           1  G20PRERTRU        732       red
#
# [1972 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=(5, 4))
state_shape.plot(ax=ax, color=state_shape['max_color'])

plt.title("GeoDataFrame with Maximum Value Colors")
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.show()
